# %%
from marvin.tools.maps import Maps
# Out:
# /home/sshamsi/miniconda3/envs/marvin/lib/python3.9/site-packages/marvin/core/exceptions.py:50: UserWarning: cannot initiate Sentry error reporting: [Errno 25] Inappropriate ioctl for device.
#   warnings.warn('cannot initiate Sentry error reporting: {0}.'.format(str(ee)),
# [INFO]: No release version set. Setting default to MPL-11
# [WARNING]: path /home/sshamsi/sas/mangawork/manga/spectro/analysis/v3_1_1/3.1.0/dapall-v3_1_1-3.1.0.fits cannot be found. Setting dapall to None. (MarvinUserWarning)

# %%
maps = Maps('1-260943')

# %%
import sys, os

# %%
sys.path.append('../../GZ3D_production/')

# %%
import gz3d_fits

# %%
data = gz3d_fits.gz3d_fits('/home/sshamsi/sas/mangawork/manga/sandbox/galaxyzoo3d/v3_0_0/1-260943_127_14722620.fits.gz')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,12))
plt.imshow(data.image)
plt.xticks([])
plt.yticks([])
plt.savefig('coolgal.png')

# %%
data.metadata
# Out:
# <Table length=1>
#     ra      dec    MANGAID  ... GZ_bar_votes GZ_spiral_votes  sample
#  float32  float32   str11   ...    int16          int16       str70
# --------- -------- -------- ... ------------ --------------- --------
# 212.63185 38.89353 1-260943 ...            6              39 original
