# %% [markdown]
# We'll attempt to plot our target sample of galaxies over MaNGA's entire sample, to see where most of our sample galaxies lie with respect to the overall MaNGA data.

# %%
from astropy.io import fits
import numpy as np
from marvin.tools.maps import Maps
import matplotlib.pyplot as plt
# Out:
# /home/sshamsi/miniconda3/envs/marvin/lib/python3.9/site-packages/marvin/core/exceptions.py:50: UserWarning: cannot initiate Sentry error reporting: [Errno 25] Inappropriate ioctl for device.
#   warnings.warn('cannot initiate Sentry error reporting: {0}.'.format(str(ee)),
# [INFO]: No release version set. Setting default to MPL-11

# %%
plt.style.use('seaborn')
plt.style.use('seaborn-colorblind')

# %%
hdu_drp = fits.open('/home/sshamsi/sas/mangawork/manga/spectro/redux/v3_1_1/drpall-v3_1_1.fits')

# %%
hdu_drp[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1614 / length of dimension 1
# NAXIS2  =                11273 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   99 / number of table fields
# TTYPE1  = 'plate   '
# TFORM1  = 'K       '
# TTYPE2  = 'ifudsgn '
# TFORM2  = '32A     '
# TTYPE3  = 'plateifu'
# TFORM3  = '32A     '
# TTYPE4  = 'mangaid '
# TFORM4  = '32A     '
# TTYPE5  = 'versdrp2'
# TFORM5  = '32A     '
# TTYPE6  = 'versdrp3'
# TFORM6  = '32A     '
# TTYPE7  = 'verscore'
# TFORM7  = '32A     '
# TTYPE8  = 'versutil'
# TFORM8  = '32A     '
# TTYPE9  = 'versprim'
# TFORM9  = '32A     '
# TTYPE10 = 'platetyp'
# TFORM10 = '32A     '
# TTYPE11 = 'srvymode'
# TFORM11 = '32A     '
# TTYPE12 = 'objra   '
# TFORM12 = 'D       '
# TTYPE13 = 'objdec  '
# TFORM13 = 'D       '
# TTYPE14 = 'ifuglon '
# TFORM14 = 'D       '
# TTYPE15 = 'ifuglat '
# TFORM15 = 'D       '
# TTYPE16 = 'ifura   '
# TFORM16 = 'D       '
# TTYPE17 = 'ifudec  '
# TFORM17 = 'D       '
# TTYPE18 = 'ebvgal  '
# TFORM18 = 'D       '
# TTYPE19 = 'nexp    '
# TFORM19 = 'K       '
# TTYPE20 = 'exptime '
# TFORM20 = 'D       '
# TTYPE21 = 'drp3qual'
# TFORM21 = 'K       '
# TTYPE22 = 'bluesn2 '
# TFORM22 = 'D       '
# TTYPE23 = 'redsn2  '
# TFORM23 = 'D       '
# TTYPE24 = 'harname '
# TFORM24 = '53A     '
# TTYPE25 = 'frlplug '
# TFORM25 = 'K       '
# TTYPE26 = 'cartid  '
# TFORM26 = '32A     '
# TTYPE27 = 'designid'
# TFORM27 = 'K       '
# TTYPE28 = 'cenra   '
# TFORM28 = 'D       '
# TTYPE29 = 'cendec  '
# TFORM29 = 'D       '
# TTYPE30 = 'airmsmin'
# TFORM30 = 'D       '
# TTYPE31 = 'airmsmed'
# TFORM31 = 'D       '
# TTYPE32 = 'airmsmax'
# TFORM32 = 'D       '
# TTYPE33 = 'seemin  '
# TFORM33 = 'D       '
# TTYPE34 = 'seemed  '
# TFORM34 = 'D       '
# TTYPE35 = 'seemax  '
# TFORM35 = 'D       '
# TTYPE36 = 'transmin'
# TFORM36 = 'D       '
# TTYPE37 = 'transmed'
# TFORM37 = 'D       '
# TTYPE38 = 'transmax'
# TFORM38 = 'D       '
# TTYPE39 = 'mjdmin  '
# TFORM39 = 'K       '
# TTYPE40 = 'mjdmed  '
# TFORM40 = 'K       '
# TTYPE41 = 'mjdmax  '
# TFORM41 = 'K       '
# TTYPE42 = 'gfwhm   '
# TFORM42 = 'D       '
# TTYPE43 = 'rfwhm   '
# TFORM43 = 'D       '
# TTYPE44 = 'ifwhm   '
# TFORM44 = 'D       '
# TTYPE45 = 'zfwhm   '
# TFORM45 = 'D       '
# TTYPE46 = 'mngtarg1'
# TFORM46 = 'K       '
# TTYPE47 = 'mngtarg2'
# TFORM47 = 'K       '
# TTYPE48 = 'mngtarg3'
# TFORM48 = 'K       '
# TTYPE49 = 'catidnum'
# TFORM49 = 'K       '
# TTYPE50 = 'plttarg '
# TFORM50 = '32A     '
# TTYPE51 = 'manga_tileid'
# TFORM51 = 'K       '
# TTYPE52 = 'nsa_iauname'
# TFORM52 = '19A     '
# TTYPE53 = 'ifudesignsize'
# TFORM53 = 'K       '
# TTYPE54 = 'ifutargetsize'
# TFORM54 = 'K       '
# TTYPE55 = 'ifudesignwrongsize'
# TFORM55 = 'K       '
# TTYPE56 = 'z       '
# TFORM56 = 'D       '
# TTYPE57 = 'zmin    '
# TFORM57 = 'D       '
# TTYPE58 = 'zmax    '
# TFORM58 = 'D       '
# TTYPE59 = 'szmin   '
# TFORM59 = 'D       '
# TTYPE60 = 'szmax   '
# TFORM60 = 'D       '
# TTYPE61 = 'ezmin   '
# TFORM61 = 'D       '
# TTYPE62 = 'ezmax   '
# TFORM62 = 'D       '
# TTYPE63 = 'probs   '
# TFORM63 = 'D       '
# TTYPE64 = 'pweight '
# TFORM64 = 'D       '
# TTYPE65 = 'psweight'
# TFORM65 = 'D       '
# TTYPE66 = 'psrweight'
# TFORM66 = 'D       '
# TTYPE67 = 'sweight '
# TFORM67 = 'D       '
# TTYPE68 = 'srweight'
# TFORM68 = 'D       '
# TTYPE69 = 'eweight '
# TFORM69 = 'D       '
# TTYPE70 = 'esweight'
# TFORM70 = 'D       '
# TTYPE71 = 'esrweight'
# TFORM71 = 'D       '
# TTYPE72 = 'nsa_field'
# TFORM72 = 'K       '
# TTYPE73 = 'nsa_run '
# TFORM73 = 'K       '
# TTYPE74 = 'nsa_camcol'
# TFORM74 = 'K       '
# TTYPE75 = 'nsa_version'
# TFORM75 = '6A      '
# TTYPE76 = 'nsa_nsaid'
# TFORM76 = 'K       '
# TTYPE77 = 'nsa_nsaid_v1b'
# TFORM77 = 'K       '
# TTYPE78 = 'nsa_z   '
# TFORM78 = 'D       '
# TTYPE79 = 'nsa_zdist'
# TFORM79 = 'D       '
# TTYPE80 = 'nsa_sersic_absmag'
# TFORM80 = '7D      '
# TTYPE81 = 'nsa_elpetro_absmag'
# TFORM81 = '7D      '
# TTYPE82 = 'nsa_elpetro_amivar'
# TFORM82 = '7D      '
# TTYPE83 = 'nsa_sersic_mass'
# TFORM83 = 'D       '
# TTYPE84 = 'nsa_elpetro_mass'
# TFORM84 = 'D       '
# TTYPE85 = 'nsa_elpetro_ba'
# TFORM85 = 'D       '
# TTYPE86 = 'nsa_elpetro_phi'
# TFORM86 = 'D       '
# TTYPE87 = 'nsa_extinction'
# TFORM87 = '7D      '
# TTYPE88 = 'nsa_elpetro_th50_r'
# TFORM88 = 'D       '
# TTYPE89 = 'nsa_petro_th50'
# TFORM89 = 'D       '
# TTYPE90 = 'nsa_petro_flux'
# TFORM90 = '7D      '
# TTYPE91 = 'nsa_petro_flux_ivar'
# TFORM91 = '7D      '
# TTYPE92 = 'nsa_elpetro_flux'
# TFORM92 = '7D      '
# TTYPE93 = 'nsa_elpetro_flux_ivar'
# TFORM93 = '7D      '
# TTYPE94 = 'nsa_sersic_ba'
# TFORM94 = 'D       '
# TTYPE95 = 'nsa_sersic_n'
# TFORM95 = 'D       '
# TTYPE96 = 'nsa_sersic_phi'
# TFORM96 = 'D       '
# TTYPE97 = 'nsa_sersic_th50'
# TFORM97 = 'D       '
# TTYPE98 = 'nsa_sersic_flux'
# TFORM98 = '7D      '
# TTYPE99 = 'nsa_sersic_flux_ivar'
# TFORM99 = '7D      '
# EXTNAME = 'MANGA   '           / extension name
# CHECKSUM= 'IaYgIZXeIaXeIWXe'   / HDU checksum updated 2021-02-23T16:07:34
# DATASUM = '217557703'          / data unit checksum updated 2021-02-23T16:07:34

# %%
plateifu_arr = hdu_drp[1].data['plateifu']
mangaid_arr = hdu_drp[1].data['mangaid']
gmag_array = hdu_drp[1].data['nsa_sersic_absmag'][:,3]
rmag_array = hdu_drp[1].data['nsa_sersic_absmag'][:,4]
imag_array = hdu_drp[1].data['nsa_sersic_absmag'][:,5]
z_array = hdu_drp[1].data['nsa_Z']
mass_array = hdu_drp[1].data['nsa_sersic_mass']

# %%
sample_paths = np.load('final_sample_paths.npy', allow_pickle=True)

# %%
sample_mangaids = [path.split('/')[-1].split('_')[0] for path in sample_paths]

# %%
sample_indices = []
non_sample_indices = []

for i in range(len(mangaid_arr)):
    if mangaid_arr[i] in sample_mangaids:
        sample_indices.append(i)
    else:
        non_sample_indices.append(i)

# %%
x1 = imag_array[non_sample_indices]
y1 = np.subtract(gmag_array, rmag_array)[non_sample_indices]

# %%
filt_x1 = x1.copy()
filt_y1 = y1.copy()

indices2del = []

for i in range(len(x1)):
    if (x1[i] > -16) or (x1[i] < -25) or (y1[i] > 1.3) or (y1[i] < 0):
        indices2del.append(i)

# %%
filt_x1 = np.delete(filt_x1, indices2del)
filt_y1 = np.delete(filt_y1, indices2del)

# %%
plt.figure(figsize=(10, 8))

hb = plt.hexbin(filt_x1, filt_y1, gridsize=15, cmap=plt.get_cmap('Purples'))
plt.scatter(imag_array[sample_indices], np.subtract(gmag_array, rmag_array)[sample_indices], marker = '.',
            label='Spiral Galaxy Sample', color='green')

cb = plt.colorbar(hb)
cb.set_label('# Galaxies in total MaNGA Sample', size=17, labelpad=20)
#plt.scatter(imag_array[non_sample_indices], np.subtract(gmag_array, rmag_array)[non_sample_indices], marker='x',
#            label='Total MaNGA Sample')

plt.xlim(-16, -25)
plt.ylim(0, 1.3)

plt.xlabel('Absolute Magnitude  $[i]$', size=20, labelpad = 15)
plt.ylabel('$g - r$', size=20, labelpad = 15)

plt.xticks(size=15)
plt.yticks(size=15)

plt.legend(fontsize=13)

# %%
mass_array_lg = np.log10(mass_array)
# Out:
# [WARNING]: invalid value encountered in log10 (RuntimeWarning)

# %%
x2 = mass_array_lg[non_sample_indices]
y2 = z_array[non_sample_indices]

# %%
filt_x2 = x2.copy()
filt_y2 = y2.copy()

indices2del2 = []

for i in range(len(x2)):
    if (x2[i] > 12) or (x2[i] < 8) or (y2[i] > 0.16) or (y2[i] < 0):
        indices2del2.append(i)

# %%
len(indices2del2)
# Out:
# 1046

# %%
filt_x2 = np.delete(filt_x2, indices2del2)
filt_y2 = np.delete(filt_y2, indices2del2)

# %%
plt.figure(figsize=(11, 8))

hb = plt.hexbin(filt_x2, filt_y2, gridsize=15, cmap=plt.get_cmap('Purples'))
#plt.scatter(mass_array_lg[non_sample_indices], z_array[non_sample_indices], marker='x',
#            label='Total MaNGA Sample')
plt.scatter(mass_array_lg[sample_indices], z_array[sample_indices], marker = '.',
            label='Spiral Galaxy Sample', color='green')

cb = plt.colorbar(hb)
cb.set_label('# Galaxies in total MaNGA Sample', size=17, labelpad=20)

plt.xlim(8, 12)
plt.ylim(0, 0.16)

plt.xlabel('Stellar Mass   $lg(M_\odot)$', size=20, labelpad = 15)
plt.ylabel('Redshift   $z$', size=20, labelpad = 15)

plt.xticks(size=15)
plt.yticks(size=15)

plt.legend(fontsize=14)
